# %% [markdown]
# # return statement
# - Function can take input values as parameters and executes business logic, and returns output to the caller with return statement.
# - Python function can return any number of values at a time by using a return statement.
# - Default return value of any python function is None.

# %%
# Example to write a function to accept 2 numbers as input and return sum. 
def add(x,y): 
    return x+y 
result=add(10,20) 
print("The sum is",result) 
print("The sum is",add(100,200))
# Out:
# The sum is 30
# The sum is 300

# %%
# Example
def f1(): 
    print("Hello") 
f1() 
print(f1())
# Out:
# Hello
# Hello
# None

# %%
# Program to check whether the number is odd or even
def even_odd(num): 
    if num%2==0: 
        print(num,"is Even Number") 
    else: 
        print(num,"is Odd Number") 
even_odd(10) 
even_odd(5)
# Out:
# 10 is Even Number
# 5 is Odd Number

# %%
# program for Factorial 
def fact(num): 
    result=1 
    while num>=1: 
        result=result*num          # Did not understand these concept 
        num=num-1 
    return result 
for i in range(1,5): 
    print("The Factorial of",i,"is :",fact(i))
# Out:
# The Factorial of 1 is : 1
# The Factorial of 2 is : 2
# The Factorial of 3 is : 6
# The Factorial of 4 is : 24

# %%
# Example for keyword argument
def calc(a,b):     # keyword arguments  
    sum = a + b 
    sub = a - b 
    mul = a * b 
    div = a / b 
    return sum,sub,mul,div 
t = calc(a = 100, b = 50)   
for x in t: 
    print(x)
# Out:
# 150
# 50
# 5000
# 2.0

# %%
# Another Example
def wish(name,msg): 
    print('Hello',name,msg) 
    wish(name = 'SAIF',msg = 'Good Morning')          # Did not understand it is printing number of times
#order is not important, but no.of arguments is important 
wish(msg = 'Good Morning',name = 'SAIF')
# Out:
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# Hello SAIF Good Morning
# ...

# %%
# Example
def wish(msg,name ='Guest'): 
    print(msg,name) 
wish('Hello','Saif')
# Out:
# Hello Saif

# %%
# Another Example
def wish(name ='Guest',msg='Good Morning'): 
    print('Hello',name,msg) 
wish()
# Out:
# Hello Guest Good Morning

# %%
# Example
def wish(marks,age,name = 'Guest', msg = 'Good Morning'): 
    print('Student Name:',name) 
    print('Student Age:',age) 
    print('Student Marks:',marks) 
    print('Message:',msg) 
wish(99,21,'Saifulla')
# Out:
# Student Name: Saifulla
# Student Age: 21
# Student Marks: 99
# Message: Good Morning

# %%
# Example
def sum(a,b,c): 
    print(a+b+c) 
sum(10,20,30,40) # here it shows error because we given 4 numbers it requires only 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 def sum(a,b,c):
#       3     print(a+b+c)
# ----> 4 sum(10,20,30,40) # here it shows error because we given 4 numbers it requires only 3
#
# TypeError: sum() takes 3 positional arguments but 4 were given

# %%
# So if we give 3 then it will execute
def sum(a,b,c): 
    print(a+b+c) 
sum(10,20,30)
# We can use similar example
# So if we give 3 then it will execute
def sum(a,b,c,d): 
    print(a+b+c+d) 
sum(10,20,30,40)
# Out:
# 60
# 100

# %% [markdown]
#  If you change the number of arguments, then automatically for every change, compulsorily we need to go for new function unnecessarily. Because of this length of the code is going to increase. To overcome this problem we should go for variable length arguments.

# %%
# Example
def sum(*n):  # Here, 'n' is a variable length argument.  
    result =0 
    for x in n: 
        result = result + x 
    print(result) 
sum(10,20,30,40)
# Out:
# 100

# %%
# Another Example
def sum(*n):    
    result =0 
    for x in n: 
        result = result + x 
    print(result) 
sum(10)
# Out:
# 10

# %%
# Example
def sum(*n):     
    result =0 
    for x in n: 
        result = result + x  # Here, 'n' is a variable length argument.  
    print('The Sum is : ', result) 
sum(10,20,30,40) 
sum(10,20,30) 
sum(10,20) 
sum(10) 
sum()
# Out:
# The Sum is :  100
# The Sum is :  60
# The Sum is :  30
# The Sum is :  10
# The Sum is :  0
